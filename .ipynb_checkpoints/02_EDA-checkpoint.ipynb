# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
sns.set_style("whitegrid")

# %%
df = pd.read_csv('Telco_Cusomer_Churn.csv')

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
df.dropna(inplace=True)

# %%
df.drop('customerID',axis=1,inplace=True)

# %%
churn_rate = df['Churn'].value_counts(normalize=True)*100

print(churn_rate)
# Out:
# Churn
# No     73.421502
# Yes    26.578498
# Name: proportion, dtype: float64

# %%
sns.countplot(x='Churn',data=df)
plt.title('Customer Churn Distribution')
plt.show()

# %% [markdown]
# Approximately 26.5% customers have churned while 73.5% remained.

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    x='Churn',
    y='tenure',
    data=df
)
plt.title('Tenure vs Churn')
plt.show()

# %% [markdown]
# Customers who churn tend to have significantly lower tenure,
# New customers are more likely to leave the company.

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    x='Churn',
    y='MonthlyCharges',
    data = df 
)

plt.title('Monthly Charges Vs Churn')
plt.show()

# %% [markdown]
# Customers with higher monthly charges show higher churn rates,
# Expensive plans may increase churn risk.

# %%
contract_churn = pd.crosstab(
    df['Contract'],
    df['Churn'],
    normalize='index'
)*100

contract_churn
# Out:
# Churn                  No        Yes
# Contract
# Month-to-month  57.290323  42.709677
# One year        88.722826  11.277174
# Two year        97.151335   2.848665

# %%
contract_churn['Yes'].sort_values().plot(
    kind='bar'
)

plt.ylabel("Churn %")

plt.title("Churn Percentage by Contract Type")

plt.show()

# %% [markdown]
# Month-to-month customers have the highest churn rate,
# Long-term contracts significantly improve retention.
